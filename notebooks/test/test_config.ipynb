# %%
from vnstock_forecast.engine.data import updater
from vnstock_forecast.engine.utils import config_utils
from vnstock_forecast.config import to_app_config

# %%
cfg = to_app_config(config_utils.load_config())

# %%
config_utils.print_config(cfg)
# Out:
# data:
#   discovery:
#     symbols: {}
#     resolutions:
#       vietstock:
#         daily: D
#         m1: 1
#         m5: 5
#         m15: 15
#         m30: 30
#         m45: 45
#         h1: 60
#         h3: 180
#         h4: 240
#   updater:
#     client: vietstock
#     symbols:
#     - YEG
#     - YBM
#     - VVS
#     - VTP
#     - VTO
#     - VTB
#     - VSI
#     - VSH
#     - VSC
#     - VRE
#     - VRC
#     - VPX
#     - VPS
#     - VPL
#     - VPI
#     - VPH
#     - VPG
#     - VPD
#     - VPB
#     - VOS
#     - VNS
#     - VNM
#     - VNL
#     - VNG
#     - VNE
#     - VND
#     - VMD
#     - VJC
#     - VIX
#     - VIP
#     - VID
#     - VIC
#     - VIB
#     - VHM
#     - VHC
#     - VGC
#     - VFG
#     - VDS
#     - VDP
#     - VCK
#     - VCI
#     - VCG
#     - VCF
#     - VCB
#     - VCA
#     - VAF
#     - VAB
#     - UIC
#     - TYA
#     - TVT
#     - TVS
#     - TVB
#     - TV2
#     - TTF
#     - TTE
#     - TTA
#     - TSC
#     - TSA
#     - TRC
# ...
