# %%
from vnstock_forecast.utils import config_utils
from vnstock_forecast.utils import env_utils
from vnstock_forecast.schemas import AppConfig

# %%
import hydra
from omegaconf import OmegaConf
from omegaconf import DictConfig
import omegaconf
from vnstock_forecast.shared.path import CONFIG_PATH_STR

# %%
from vnstock_forecast.schemas.config import load_app_config
from vnstock_forecast.utils.config_utils import load_config
cfg = load_app_config()

# %%
config_utils.print_config(cfg)
# Out:
# data:
#   discovery:
#     symbols:
#       hnx_stock:
#       - X20
#       - WSS
#       - WCS
#       - VTZ
#       - VTV
#       - VTJ
#       - VTH
#       - VTC
#       - VSM
#       - VSA
#       - VNT
#       - VNR
#       - VNF
#       - VNC
#       - VMS
#       - VMC
#       - VLA
#       - VIT
#       - VIG
#       - VIF
#       - VHL
#       - VHE
#       - VGS
#       - VGP
#       - VFS
#       - VE4
#       - VE3
#       - VE1
#       - VDL
#       - VCS
#       - VCM
#       - VCC
#       - VC9
#       - VC7
#       - VC6
#       - VC3
#       - VC2
#       - VC1
#       - VBC
#       - V21
#       - V12
#       - UNI
#       - TXM
#       - TVD
#       - TVC
#       - TV4
#       - TV3
#       - TTT
#       - TTL
#       - TTH
#       - TTC
#       - TSB
#       - TPP
#       - TOT
#       - TNG
#       - TMX
#       - TMC
#       - TMB
#       - TKU
#       - TJC
#       - TIG
#       - THT
#       - THS
#       - THD
#       - THB
#       - TFC
#       - TET
# ...

# %%
print(type(cfg))
# Out:
# <class 'vnstock_forecast.schemas.config.AppConfig'>

# %%
print(cfg.data.updater.symbols)
# Out:
# ['SHB', 'VHM']
